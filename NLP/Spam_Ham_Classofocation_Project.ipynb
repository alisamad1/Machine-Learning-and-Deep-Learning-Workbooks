# %%
## BOW, TF-TDF, Machine Learning Algorithm

# %%
pip install chardet
# Out:
# Requirement already satisfied: chardet in c:\users\kiit\anaconda3\lib\site-packages (4.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import chardet

with open('spam.csv', 'rb') as f:
    result = chardet.detect(f.read(10000))
print(result)
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.726526172671652, 'language': ''}

# %%
messages = pd.read_csv('spam.csv', sep='\t', names=['label', 'message'], encoding='latin1')

# %%
messages
# Out:
#                                                   label  message
# 0                                              v1,v2,,,      NaN
# 1     ham,"Go until jurong point, crazy.. Available ...      NaN
# 2                  ham,Ok lar... Joking wif u oni...,,,      NaN
# 3     spam,Free entry in 2 a wkly comp to win FA Cup...      NaN
# 4     ham,U dun say so early hor... U c already then...      NaN
# ...                                                 ...      ...
# 5570  spam,"This is the 2nd time we have tried 2 con...      NaN
# 5571       ham,Will Ì_ b going to esplanade fr home?,,,      NaN
# 5572  ham,"Pity, * was in mood for that. So...any ot...      NaN
# 5573  ham,The guy did some bitching but I acted like...      NaN
# 5574                  ham,Rofl. Its true to its name,,,      NaN
#
# [5575 rows x 2 columns]

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\KIIT\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
corpus = []
for i in range(len(messages)):
    text = messages['message'][i]
    if isinstance(text, bytes):
        text = text.decode('utf-8', errors='ignore')  # decode bytes to string if needed
    review = re.sub('[^a-zA-Z]', ' ', text)
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if word not in stop_words]
    review = ' '.join(review)
    corpus.append(review)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 6
#       4 if isinstance(text, bytes):
#       5     text = text.decode('utf-8', errors='ignore')  # decode bytes to string if needed
# ----> 6 review = re.sub('[^a-zA-Z]', ' ', text)
#       7 review = review.lower()
#       8 review = review.split()
#
# File c:\Users\KIIT\Anaconda3\Lib\re\__init__.py:186, in sub(pattern, repl, string, count, flags)
#     179 def sub(pattern, repl, string, count=0, flags=0):
#     180     """Return the string obtained by replacing the leftmost
#     181     non-overlapping occurrences of the pattern in string by the
#     182     replacement repl.  repl can be either a string or a callable;
#     183     if a string, backslash escapes in it are processed.  If it is
#     184     a callable, it's passed the Match object and must return
#     185     a replacement string to be used."""
# --> 186     return _compile(pattern, flags).sub(repl, string, count)
#
# TypeError: cannot use a string pattern on a bytes-like object

# %%
corpus

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=2500, ngram_range = (1,2))

# %%
X = cv.fit_transform(corpus).toarray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 X = cv.fit_transform(corpus).toarray()
#
# File c:\Users\KIIT\Anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\KIIT\Anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:1372, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1364             warnings.warn(
#    1365                 "Upper case characters found in"
#    1366                 " vocabulary while 'lowercase'"
#    1367                 " is True. These entries will not"
#    1368                 " be matched with any documents"
#    1369             )
#    1370             break
# -> 1372 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1374 if self.binary:
#    1375     X.data.fill(1)
#
# File c:\Users\KIIT\Anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:1278, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1276     vocabulary = dict(vocabulary)
#    1277     if not vocabulary:
# -> 1278         raise ValueError(
#    1279             "empty vocabulary; perhaps the documents only contain stop words"
#    1280         )
#    1282 if indptr[-1] > np.iinfo(np.int32).max:  # = 2**31 - 1
#    1283     if _IS_32BIT:
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
import numpy as np
np.set_printoptions(edgeitems = 30, linewidth = 100000, 
                    formatter = dict(float = lambda x: "%.3g" % X))
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       1 import numpy as np
#       2 np.set_printoptions(edgeitems = 30, linewidth = 100000,
#       3                     formatter = dict(float = lambda x: "%.3g" % X))
# ----> 4 X
#
# NameError: name 'X' is not defined

# %%
y = pd.get_dummies(messages['label'])

# %%
y
# Out:
#       ham""",,,  \
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 5570      False
# 5571      False
# 5572      False
# 5573      False
# 5574      False
#
#       ham""",Well there's still a bit left if you guys want to tonight,,  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5570                                              False
# 5571                                              False
# 5572                                              False
# 5573                                              False
# 5574                                              False
#
#       ham, &lt;#&gt;  in mca. But not conform.,,,  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ...                                           ...
# 5570                                        False
# 5571                                        False
# 5572                                        False
# 5573                                        False
# 5574                                        False
#
#       ham, &lt;#&gt;  mins but i had to stop somewhere first.,,,  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5570                                              False
# 5571                                              False
# 5572                                              False
# 5573                                              False
# 5574                                              False
#
#       ham, &lt;DECIMAL&gt; m but its not a common car here so its better to buy from china or asia. Or if i find it less expensive. I.ll holla,,,  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5570                                              False
# 5571                                              False
# 5572                                              False
# 5573                                              False
# 5574                                              False
#
#       ham, and  picking them up from various points,,,  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ...                                                ...
# 5570                                             False
# 5571                                             False
# 5572                                             False
# 5573                                             False
# 5574                                             False
#
#       ham, gonna let me know cos comes bak from holiday that day.  is coming. Don't4get2text me  number. ,,,  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5570                                              False
# 5571                                              False
# 5572                                              False
# 5573                                              False
# 5574                                              False
#
#       ham, what number do u live at? Is it 11?,,,  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ...                                           ...
# 5570                                        False
# 5571                                        False
# 5572                                        False
# 5573                                        False
# 5574                                        False
#
#       ham," came to look at the flat, seems ok, in his 50s? * Is away alot wiv work. Got woman coming at 6.30 too.",,,  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5570                                              False
# 5571                                              False
# 5572                                              False
# 5573                                              False
# 5574                                              False
#
#       ham," said kiss, kiss, i can't do the sound effects! He is a gorgeous man isn't he! Kind of person who needs a smile to brighten his day! ",,,  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5570                                              False
# 5571                                              False
# 5572                                              False
# 5573                                              False
# 5574                                              False
#
#       ...  spam,ringtoneking 84484,,,  \
# 0     ...                       False
# 1     ...                       False
# 2     ...                       False
# 3     ...                       False
# 4     ...                       False
# ...   ...                         ...
# 5570  ...                       False
# 5571  ...                       False
# 5572  ...                       False
# 5573  ...                       False
# 5574  ...                       False
#
#       spam,sexy sexy cum and text me im wet and warm and ready for some porn! u up for some fun? THIS MSG IS FREE RECD MSGS 150P INC VAT 2 CANCEL TEXT STOP,,,  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5570                                              False
# 5571                                              False
# 5572                                              False
# 5573                                              False
# 5574                                              False
#
#       spam,sports fans - get the latest sports news str* 2 ur mobile 1 wk FREE PLUS a FREE TONE Txt SPORT ON to 8007 www.getzed.co.uk 0870141701216+ norm 4txt/120p ,,,  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5570                                              False
# 5571                                              False
# 5572                                              False
# 5573                                              False
# 5574                                              False
#
#       spam,tells u 2 call 09066358152 to claim å£5000 prize. U have 2 enter all ur mobile & personal details @ the prompts. Careful!,,,  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5570                                              False
# 5571                                              False
# 5572                                              False
# 5573                                              False
# 5574                                              False
#
#       spam,thesmszone.com lets you send free anonymous and masked messages..im sending this message from there..do you see the potential for abuse???,,,  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5570                                              False
# 5571                                              False
# 5572                                              False
# 5573                                              False
# 5574                                              False
#
#       spam,todays vodafone numbers ending with 0089(my last four digits) are selected to received a å£350 award. If your number matches please call 09063442151 to claim your å£350 award,,,  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5570                                              False
# 5571                                              False
# 5572                                              False
# 5573                                              False
# 5574                                              False
#
#       spam,u r a winner U ave been specially selected 2 receive å£1000 cash or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810710p/min (18 ),,,  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5570                                              False
# 5571                                              False
# 5572                                              False
# 5573                                              False
# 5574                                              False
#
#       spam,wamma get laid?want real doggin locations sent direct to your mobile? join the UKs largest dogging network. txt dogs to 69696 now!nyt. ec2a. 3lp å£1.50/msg.,,,  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5570                                              False
# 5571                                              False
# 5572                                              False
# 5573                                              False
# 5574                                              False
#
#       spam,we tried to contact you re your response to our offer of a new nokia fone and camcorder hit reply or call 08000930705 for delivery,,,  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 5570                                              False
# 5571                                              False
# 5572                                              False
# 5573                                              False
# 5574                                              False
#
#       v1,v2,,,
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 5570     False
# 5571     False
# 5572     False
# 5573     False
# 5574     False
#
# [5575 rows x 5172 columns]

# %%
y.iloc[:,0].values
# Out:
# array([False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, ..., False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False])

# %%
## train test split
from sklearn.model_selection import train_test_split
X_train , X_test, Y_train , Y_test = train_test_split(X,y, test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 ## train test split
#       2 from sklearn.model_selection import train_test_split
# ----> 3 X_train , X_test, Y_train , Y_test = train_test_split(X,y, test_size=0.2)
#
# NameError: name 'X' is not defined

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
spam_detect_model = MultinomialNB().fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 spam_detect_model = MultinomialNB().fit(X_train, Y_train)
#
# NameError: name 'X_train' is not defined

# %%
spam_detect_model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 spam_detect_model
#
# NameError: name 'spam_detect_model' is not defined

# %%
y_pred = spam_detect_model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 y_pred = spam_detect_model.predict(X_test)
#
# NameError: name 'spam_detect_model' is not defined

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
accuracy_score(X_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 accuracy_score(X_test, y_pred)
#
# NameError: name 'X_test' is not defined
