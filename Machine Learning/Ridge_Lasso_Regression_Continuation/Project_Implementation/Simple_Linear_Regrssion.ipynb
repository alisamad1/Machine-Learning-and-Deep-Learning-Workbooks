# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("SOCR-HeightWeight.csv")

# %%
df.head(5)
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
df.isnull().sum()
# Out:
# Index             0
# Height(Inches)    0
# Weight(Pounds)    0
# dtype: int64

# %%
#scatter plot
plt.scatter(df['Height(Inches)'], df['Weight(Pounds)'])
plt.xlabel("Height")
plt.ylabel("weight")
# Out:
# Text(0, 0.5, 'weight')

# %%
plt.show()

# %%
df.corr()
# Out:
#                    Index  Height(Inches)  Weight(Pounds)
# Index           1.000000        0.009626       -0.007257
# Height(Inches)  0.009626        1.000000        0.502859
# Weight(Pounds) -0.007257        0.502859        1.000000

# %%
## Seaborn for cvisualiztion
import seaborn as sns
sns.pairplot(df)

# %%
## Independent and dependent features
df.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
## Independent and dependent features
X = df[['Height(Inches)']] ## independent featyres should be data frame or 2-d array
X.head()
y = df['Weight(Pounds)']

# %%
X= df['Height(Inches)']
np.array(X).shape
# Out:
# (25000,)

# %%
X
# Out:
# 0        65.78331
# 1        71.51521
# 2        69.39874
# 3        68.21660
# 4        67.78781
#            ...
# 24995    69.50215
# 24996    64.54826
# 24997    64.69855
# 24998    67.52918
# 24999    68.87761
# Name: Height(Inches), Length: 25000, dtype: float64

# %%
y
# Out:
# 0        112.9925
# 1        136.4873
# 2        153.0269
# 3        142.3354
# 4        144.2971
#            ...
# 24995    118.0312
# 24996    120.1932
# 24997    118.2655
# 24998    132.2682
# 24999    124.8742
# Name: Weight(Pounds), Length: 25000, dtype: float64

# %%
np.array(y).shape
# Out:
# (25000,)

# %%
## train test split
from sklearn.model_selection import train_test_split
X_train , X_test, y_train, y_test = train_test_split(X,y,test_size=0.5, random_state=42)

# %%
X_train.shape
# Out:
# (12500,)

# %%
## standardization
## we apply z-score with mean = 0 and SD = 1
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 scaler = StandardScaler()
# ----> 2 scaler.fit_transform(X_train)
#
# File c:\Users\KIIT\Anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File c:\Users\KIIT\Anaconda3\Lib\site-packages\sklearn\base.py:1098, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1083         warnings.warn(
# ...

# %%
X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 X_test = scaler.transform(X_test)
#
# File c:\Users\KIIT\Anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File c:\Users\KIIT\Anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:1042, in StandardScaler.transform(self, X, copy)
#    1027 def transform(self, X, copy=None):
# ...

# %%
## Applying Linear Regression Model
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression(n_jobs= 1)

# %%
regression.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 regression.fit(X_train,y_train)
#
# File c:\Users\KIIT\Anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\KIIT\Anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
#     607 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 609 X, y = self._validate_data(
#     610     X,
#     611     y,
# ...

# %%
print("coeffecient or Slope :", regression.coef_)
print("Intercept :", regression.intercept_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 print("coeffecient or Slope :", regression.coef_)
#       2 print("Intercept :", regression.intercept_)
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
## plot training data plot best fit line
plt.scatter(X_train, y_train)
plt.plot(X_train, regression.predict(X_train))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[49], line 3
#       1 ## plot training data plot best fit line
#       2 plt.scatter(X_train, y_train)
# ----> 3 plt.plot(X_train, regression.predict(X_train))
#
# File c:\Users\KIIT\Anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File c:\Users\KIIT\Anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:283, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
# --> 283     check_is_fitted(self)
#     285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
# ...

# %%
##prediction for test data
regression.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[50], line 2
#       1 ##prediction for test data
# ----> 2 regression.predict(X_test)
#
# File c:\Users\KIIT\Anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File c:\Users\KIIT\Anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:283, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
# --> 283     check_is_fitted(self)
#     285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#
# ...

# %%
## performance metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error,root_mean_squared_error

# %%
mse = mean_squared_error(y_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 mse = mean_squared_error(y_test)
#
# File c:\Users\KIIT\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
# --> 191 params = func_sig.bind(*args, **kwargs)
#     192 params.apply_defaults()
#     194 # ignore self/cls and positional/keyword markers
#
# File c:\Users\KIIT\Anaconda3\Lib\inspect.py:3273, in Signature.bind(self, *args, **kwargs)
#    3268 def bind(self, /, *args, **kwargs):
#    3269     """Get a BoundArguments object, that maps the passed `args`
#    3270     and `kwargs` to the function's signature.  Raises `TypeError`
#    3271     if the passed arguments can not be bound.
#    3272     """
# ...
